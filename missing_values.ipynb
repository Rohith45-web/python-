# %%
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\rohit\OneDrive\Desktop\python\venv\Library\data.csv')

# %%
import pandas as pd

# %%
df
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
df.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
df.isnull().sum()
# Out:
# Brands                   0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount percentage      0
# dtype: int64

# %%
df.shape
# Out:
# (3114, 12)

# %%
sns.displot(df['Selling Price'],kde=True)

# %%
df['Selling Price'].mean()
# Out:
# np.float64(26436.625561978162)

# %%
df['Selling Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Selling Price mean'] = df['Selling Price'].fillna(df['Selling Price'].mean(),inplace=True)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_47512\1452016080.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Selling Price mean'] = df['Selling Price'].fillna(df['Selling Price'].mean(),inplace=True)

# %%
df['Selling Price mean']
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 3109    None
# 3110    None
# 3111    None
# 3112    None
# 3113    None
# Name: Selling Price mean, Length: 3114, dtype: object

# %%
df['Selling Price'].describe()
# Out:
# count      3114.000000
# mean      26436.625562
# std       30066.892622
# min        1000.000000
# 25%        9990.000000
# 50%       15000.000000
# 75%       28999.000000
# max      179900.000000
# Name: Selling Price, dtype: float64

# %%
df['Selling Price'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3109    False
# 3110    False
# 3111    False
# 3112    False
# 3113    False
# Name: Selling Price, Length: 3114, dtype: bool

# %%
df.isnull().sum()
# Out:
# Brands                    0
# Models                    0
# Colors                    0
# Memory                   43
# Storage                  39
# Camera                    0
# Rating                  144
# Selling Price             0
# Original Price            0
# Mobile                    0
# Discount                  0
# discount percentage       0
# Selling Price mean     3114
# rating median             0
# rating mode             144
# dtype: int64

# %%
df['Rating'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3109    False
# 3110    False
# 3111    False
# 3112     True
# 3113    False
# Name: Rating, Length: 3114, dtype: bool

# %%
df['rating mean'] = df['Rating'].fillna(df['Rating'].mean())

# %%
df[['rating mean','Rating']]
# Out:
#       rating mean  Rating
# 0        4.300000     4.3
# 1        3.800000     3.8
# 2        4.400000     4.4
# 3        4.200000     4.2
# 4        4.600000     4.6
# ...           ...     ...
# 3109     4.400000     4.4
# 3110     3.600000     3.6
# 3111     4.500000     4.5
# 3112     4.243098     NaN
# 3113     4.200000     4.2
#
# [3114 rows x 2 columns]

# %%
df['Colors'].value_counts()
# Out:
# Colors
# Black                489
# Gold                 195
# White                154
# Blue                 146
# Silver               104
#                     ...
# Volcanic Grey          1
# CELESTIAL SILVER       1
# Titanium Sapphire      1
# Latte Gold             1
# Sapphire Gradient      1
# Name: count, Length: 639, dtype: int64

# %%
df['Colors'].mode()[0]
# Out:
# 'Black'

# %%
import numpy as np
import pandas as pd

# %%
n_samples = 100
class_0_ratio = 0.7
n_class_0 = int(n_samples * class_0_ratio)
n_class_1 = n_samples - n_class_0

# %%
n_class_1,n_class_0
# Out:
# (30, 70)

# %%
class_0= pd.DataFrame({
    'feature1': np.random.normal(loc=0, scale=1, size=n_class_0),
    'feature2': np.random.normal(loc=0, scale=2, size=n_class_0),
    'target': [0]*n_class_0
})
class_1= pd.DataFrame({
    'feature1': np.random.normal(loc=1, scale=1, size=n_class_1),
    'feature2': np.random.normal(loc=1, scale=2, size=n_class_1),
    'target': [1]*n_class_1
})

# %%
class_0
# Out:
#     feature1  feature2  target
# 0  -0.629176  3.728124       0
# 1   0.541715  4.736879       0
# 2  -0.836357  6.885336       0
# 3  -0.144189  5.829301       0
# 4   0.273955  6.825688       0
# ..       ...       ...     ...
# 65  1.396023  5.040843       0
# 66 -0.952038  3.406648       0
# 67  1.712415  7.593783       0
# 68 -0.037932  6.924579       0
# 69  0.027699  8.964188       0
#
# [70 rows x 3 columns]

# %%
df=pd.concat([class_0,class_1]).reset_index(drop=True)

# %%
df
# Out:
#     feature1  feature2  target
# 0  -0.629176  3.728124       0
# 1   0.541715  4.736879       0
# 2  -0.836357  6.885336       0
# 3  -0.144189  5.829301       0
# 4   0.273955  6.825688       0
# ..       ...       ...     ...
# 95  2.538212  6.600624       1
# 96  2.112126  9.759545       1
# 97  3.149902  7.824815       1
# 98  4.417290  5.610047       1
# 99  2.285873  8.129641       1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    feature1  feature2  target
# 0 -0.629176  3.728124       0
# 1  0.541715  4.736879       0
# 2 -0.836357  6.885336       0
# 3 -0.144189  5.829301       0
# 4  0.273955  6.825688       0

# %%
df['target'].value_counts()
# Out:
# target
# 0    70
# 1    30
# Name: count, dtype: int64

# %%
## upsampling
df_majority = df[df['target'] == 0]
df_minority = df[df['target'] == 1]

# %%
# Out:
#     feature1   feature2  target
# 70  3.812093   8.108382       1
# 71  1.893103   7.019496       1
# 72  2.582221   6.774870       1
# 73  2.348285   6.473603       1
# 74  3.985607  11.703667       1
# 75  1.481517   9.456290       1
# 76  3.423085   9.418861       1
# 77  2.407718   5.202924       1
# 78  3.925699   7.183091       1
# 79  2.633332   7.671097       1
# 80  3.265117   8.103230       1
# 81  3.467692  10.436016       1
# 82  4.241088  12.216310       1
# 83  3.096708   9.888435       1
# 84  3.091479  11.420338       1
# 85  2.565356   8.742699       1
# 86  2.221773  10.117494       1
# 87  3.681378   8.876659       1
# 88  0.417038   7.399771       1
# 89  1.510824   9.786986       1
# 90  3.964482   8.638642       1
# 91  3.952279   9.014101       1
# 92  2.200564   8.837740       1
# 93  3.074375  10.220962       1
# 94  0.303243   7.097719       1
# 95  2.538212   6.600624       1
# 96  2.112126   9.759545       1
# 97  3.149902   7.824815       1
# ...

# %%
from sklearn.utils import resample
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=70,    # to match majority class
                                 random_state=123) # reproducible results
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
df_upsampled['target'].value_counts()
# Out:
# target
# 0    70
# 1    70
# Name: count, dtype: int64

# %%
df_upsampled
# Out:
#     feature1   feature2  target
# 0  -0.629176   3.728124       0
# 1   0.541715   4.736879       0
# 2  -0.836357   6.885336       0
# 3  -0.144189   5.829301       0
# 4   0.273955   6.825688       0
# ..       ...        ...     ...
# 88  0.417038   7.399771       1
# 74  3.985607  11.703667       1
# 85  2.565356   8.742699       1
# 81  3.467692  10.436016       1
# 97  3.149902   7.824815       1
#
# [140 rows x 3 columns]

# %%
df.shape
# Out:
# (100, 3)

# %%
import seaborn as sns
