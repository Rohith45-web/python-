# %%
import pandas as pd # type: ignore

# %%
import seaborn as sns # type: ignore
# Out:
# Running cells with 'venv (Python 3.10.0)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n venv ipykernel --update-deps --force-reinstall'

# %%
## analysis 
df=pd.read_csv(r'C:\Users\rohit\OneDrive\Desktop\python\venv\Library\data.csv')

# %%
df.describe()
# Out:
#             Rating  Selling Price  Original Price      Discount  \
# count  2970.000000    3114.000000     3114.000000   3114.000000
# mean      4.243098   26436.625562    28333.473025   1896.847463
# std       0.271991   30066.892622    31525.599889   5337.126176
# min       2.300000    1000.000000     1000.000000  -8000.000000
# 25%       4.100000    9990.000000    10030.250000      0.000000
# 50%       4.300000   15000.000000    16889.500000      0.000000
# 75%       4.400000   28999.000000    31500.000000   2000.000000
# max       5.000000  179900.000000   189999.000000  75000.000000
#
#        discount percentage
# count          3114.000000
# mean              6.086788
# std              11.106776
# min            -160.320641
# 25%               0.000000
# 50%               0.000000
# 75%               9.836388
# max              70.610305

# %%
1+1
# Out:
# 2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
## finding null values or missing values
df.isnull()
# Out:
#       Brands  Models  Colors  Memory  Storage  Camera  Rating  Selling Price  \
# 0      False   False   False   False    False   False   False          False
# 1      False   False   False   False    False   False   False          False
# 2      False   False   False   False     True   False   False          False
# 3      False   False   False   False    False   False   False          False
# 4      False   False   False   False    False   False   False          False
# ...      ...     ...     ...     ...      ...     ...     ...            ...
# 3109   False   False   False   False    False   False   False          False
# 3110   False   False   False    True    False   False   False          False
# 3111   False   False   False   False    False   False   False          False
# 3112   False   False   False   False    False   False    True          False
# 3113   False   False   False   False    False   False   False          False
#
# ...

# %%
df.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 3109    False
# 3110     True
# 3111    False
# 3112     True
# 3113    False
# Length: 3114, dtype: bool

# %%
## for getting the no of missing values of a particular portion
df.isnull().sum()
# Out:
# Brands                   0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount percentage      0
# dtype: int64

# %%
df.fillna(0)
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                      0
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black      0  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
df['Rating_change'] = df['Rating'].fillna(df['Rating'].mean()).astype(int)
df
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Brands', 'Models', 'Colors', 'Memory', 'Storage', 'Camera', 'Rating',
#        'Selling Price', 'Original Price', 'Mobile', 'Discount',
#        'discount percentage'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Brands                   0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount percentage      0
# Memory_change            0
# Rating_change            0
# dtype: int64

# %%
df.drop('Memory',axis=1)
# Out:
#        Brands          Models         Colors                Storage Camera  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black                 128 GB    Yes
# 1       Nokia             3.2          Steel                  16 GB    Yes
# 2      realme             C2   Diamond Black                    NaN    Yes
# 3     Infinix          Note 5       Ice Blue                  64 GB    Yes
# 4       Apple      iPhone 11           Black                  64 GB    Yes
# ...       ...             ...            ...                    ...    ...
# 3109     POCO       M4 Pro 5G      Cool Blue                 128 GB    Yes
# 3110    Nokia             225          Black  Expandable Upto 32 GB    Yes
# 3111    Apple      iPhone SE           White                 128 GB    Yes
# 3112    Apple  iPhone 13 Pro            Gold                 128 GB    Yes
# 3113   GIONEE             F9            Blue                  32 GB    Yes
#
# ...

# %%
df.isnull().sum()
# Out:
# Brands                  0
# Models                  0
# Colors                  0
# Memory                 43
# Storage                39
# Camera                  0
# Selling Price           0
# Original Price          0
# Mobile                  0
# Discount                0
# discount percentage     0
# Memory_change           0
# Rating_change           0
# dtype: int64

# %%
## apply a function for particular column
df['new Selling Price']=df['Selling Price'].apply(lambda x:x*2)
df
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
## renaming the columns
df.rename({'Brands':'product'})
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
## data grouping
grouped_mean=df.groupby('Brands')['new Selling Price'].mean()
print(grouped_mean)
# Out:
# Brands
# ASUS             40653.830508
# Apple           163971.121447
# GIONEE           14270.186047
# Google Pixel    122783.724138
# HTC              56628.763636
# IQOO             74380.000000
# Infinix          22184.357616
# LG               38646.363636
# Lenovo           20167.685950
# Motorola         32714.933333
# Nokia            18857.314554
# OPPO             37120.976923
# POCO             33741.243243
# SAMSUNG          48592.497914
# Xiaomi           33883.818182
# realme           32793.070336
# vivo             47732.483871
# Name: new Selling Price, dtype: float64

# %%
## grouping with two category variables
grouped_mean=df.groupby(['Brands','Models'])['new Selling Price'].mean()
grouped_mean
# Out:
# Brands  Models
# ASUS    6Z               80569.428571
#         ROG              52998.000000
#         ROG 5s          107998.000000
#         ROG 5s Pro      159998.000000
#         ROG Phone 3     103331.333333
#                             ...
# vivo    Y93              23980.000000
#         Y94              31980.000000
#         Y95              37326.666667
#         Z1 Pro           33313.333333
#         Z1x              39980.000000
# Name: new Selling Price, Length: 928, dtype: float64

# %%
## aggregating multiple functins
groupped_agg=df.groupby(['Brands','Models'])['new Selling Price'].agg('mean','sum','count')
groupped_agg
# Out:
# Brands  Models
# ASUS    6Z               80569.428571
#         ROG              52998.000000
#         ROG 5s          107998.000000
#         ROG 5s Pro      159998.000000
#         ROG Phone 3     103331.333333
#                             ...
# vivo    Y93              23980.000000
#         Y94              31980.000000
#         Y95              37326.666667
#         Z1 Pro           33313.333333
#         Z1x              39980.000000
# Name: new Selling Price, Length: 928, dtype: float64

# %%
## merging and joining
df1=pd.DataFrame({'key':['A','B','C'],'value':[1,2,3]})
df2=pd.DataFrame({'key':['A','B','D'],'value':[4,5,6]})
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  value_x  value_y
# 0   A        1        4
# 1   B        2        5

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key  value_x  value_y
# 0   A      1.0      4.0
# 1   B      2.0      5.0
# 2   C      3.0      NaN
# 3   D      NaN      6.0

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  value_x  value_y
# 0   A        1      4.0
# 1   B        2      5.0
# 2   C        3      NaN

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  value_x  value_y
# 0   A      1.0        4
# 1   B      2.0        5
# 2   D      NaN        6
